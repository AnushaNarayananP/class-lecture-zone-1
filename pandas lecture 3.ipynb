# %%
import pandas as pd
titanic=pd.read_excel('C:\\Users\\LENOVO\\Downloads\\Titatnic.xlsx')
new_titanic=titanic

# %%
student1=pd.read_csv('C:\\Users\\LENOVO\\Downloads\\student1.csv')
new_student1=student1

# %%
dirtydata=pd.read_csv('C:\\Users\\LENOVO\\Downloads\\dirtydata.csv')
new_dirtydata=dirtydata

# %%
titanic
# Out:
#      PassengerId                                               Name  Pclass  \
# 0              1                            Braund, Mr. Owen Harris       3
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2              3                             Heikkinen, Miss. Laina       3
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4              5                           Allen, Mr. William Henry       3
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas       2
# 887          888                       Graham, Miss. Margaret Edith       1
# 888          889           Johnston, Miss. Catherine Helen "Carrie"       3
# 889          890                              Behr, Mr. Karl Howell       1
# 890          891                                Dooley, Mr. Patrick       3
#
# ...

# %%
student1
# Out:
#        name  gmat  gpa  exp  admitted country
# 0     samir   780  4.0    3         1     Ind
# 1   kaushal   750  3.9    4         1     Ind
# 2    nandan   690  3.3    3         0     Ind
# 3     ankit   710  3.7    5         1      us
# 4   deepika   680  3.9    4         0     Ind
# 5    kshama   730  3.7    6         1     Ind
# 6    gaurav   690  2.3    1         0      us
# 7      john   720  3.3    4         1      us
# 8      nida   740  3.3    5         1     Ind
# 9     samir   690  1.7    1         0     Ind
# 10  kaushal   610  2.7    3         0     Ind
# 11   nandan   690  3.7    5         1     Ind
# 12    ankit   710  3.7    6         1      us
# 13  deepika   680  3.3    4         0     Ind
# 14   kshama   770  3.3    3         1     Ind
# 15   gaurav   510  3.0    1         0     Ind
# 16     john   580  2.7    4         0     Ind
# 17     nida   650  3.7    6         1     Ind
# 18    samir   540  2.7   24         0     Ind
# ...

# %%
dirtydata
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'  110.0       130     409.1
# 1         60  '2020/12/02'  117.0       145     479.0
# 2         60  '2020/12/03'  103.0       135     340.0
# 3         45  '2020/12/04'  109.0       175     282.4
# 4         45  '2020/12/05'  117.0       148     406.0
# 5         60  '2020/12/06'  102.0       127     300.0
# 6         60  '2020/12/07'  110.0       136     374.0
# 7        450  '2020/12/08'  104.0       134     253.3
# 8         30  '2020/12/09'  109.0       133     195.1
# 9         60  '2020/12/10'   98.0       124     269.0
# 10        60  '2020/12/11'  103.0       147     329.3
# 11        60  '2020/12/12'  100.0       120     250.7
# 12        60  '2020/12/12'  100.0       120     250.7
# 13        60  '2020/12/13'    NaN       128     345.3
# 14        60  '2020/12/14'  104.0       132     379.3
# 15        60  '2020/12/15'   98.0       123     275.0
# ...

# %%
titanic
# Out:
#      PassengerId                                               Name  Pclass  \
# 0              1                            Braund, Mr. Owen Harris       3
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2              3                             Heikkinen, Miss. Laina       3
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4              5                           Allen, Mr. William Henry       3
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas       2
# 887          888                       Graham, Miss. Margaret Edith       1
# 888          889           Johnston, Miss. Catherine Helen "Carrie"       3
# 889          890                              Behr, Mr. Karl Howell       1
# 890          891                                Dooley, Mr. Patrick       3
#
# ...

# %%
titanic.shape
# Out:
# (891, 12)

# %%
titanic.head()
# Out:
#    PassengerId                                               Name  Pclass  \
# 0            1                            Braund, Mr. Owen Harris       3
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2            3                             Heikkinen, Miss. Laina       3
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4            5                           Allen, Mr. William Henry       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#    Survived
# 0         0
# 1         1
# 2         1
# 3         1
# 4         0

# %%
titanic.head(8)
# Out:
#    PassengerId                                               Name  Pclass  \
# 0            1                            Braund, Mr. Owen Harris       3
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2            3                             Heikkinen, Miss. Laina       3
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4            5                           Allen, Mr. William Henry       3
# 5            6                                   Moran, Mr. James       3
# 6            7                            McCarthy, Mr. Timothy J       1
# 7            8                     Palsson, Master. Gosta Leonard       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
titanic.tail(7)
# Out:
#      PassengerId                                      Name  Pclass     Sex  \
# 884          885                    Sutehall, Mr. Henry Jr       3    male
# 885          886      Rice, Mrs. William (Margaret Norton)       3  female
# 886          887                     Montvila, Rev. Juozas       2    male
# 887          888              Graham, Miss. Margaret Edith       1  female
# 888          889  Johnston, Miss. Catherine Helen "Carrie"       3  female
# 889          890                     Behr, Mr. Karl Howell       1    male
# 890          891                       Dooley, Mr. Patrick       3    male
#
#       Age  SibSp  Parch           Ticket    Fare Cabin Embarked  Survived
# 884  25.0      0      0  SOTON/OQ 392076   7.050   NaN        S         0
# 885  39.0      0      5           382652  29.125   NaN        Q         0
# 886  27.0      0      0           211536  13.000   NaN        S         0
# ...

# %%
titanic.sample()
# Out:
#      PassengerId                       Name  Pclass     Sex   Age  SibSp  \
# 419          420  Van Impe, Miss. Catharina       3  female  10.0      0
#
#      Parch  Ticket   Fare Cabin Embarked  Survived
# 419      2  345773  24.15   NaN        S         0

# %%
titanic.sample(8)
# Out:
#      PassengerId                                       Name  Pclass     Sex  \
# 29            30                        Todoroff, Mr. Lalio       3    male
# 130          131                       Drazenoic, Mr. Jozef       3    male
# 390          391                 Carter, Mr. William Ernest       1    male
# 679          680         Cardeza, Mr. Thomas Drake Martinez       1    male
# 178          179                         Hale, Mr. Reginald       2    male
# 746          747                Abbott, Mr. Rossmore Edward       3    male
# 471          472                            Cacic, Mr. Luka       3    male
# 194          195  Brown, Mrs. James Joseph (Margaret Tobin)       1  female
#
#       Age  SibSp  Parch     Ticket      Fare        Cabin Embarked  Survived
# 29    NaN      0      0     349216    7.8958          NaN        S         0
# 130  33.0      0      0     349241    7.8958          NaN        C         0
# ...

# %%
pd.options.display.max_rows=891

# %%
titanic
# Out:
#      PassengerId                                               Name  Pclass  \
# 0              1                            Braund, Mr. Owen Harris       3
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2              3                             Heikkinen, Miss. Laina       3
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4              5                           Allen, Mr. William Henry       3
# 5              6                                   Moran, Mr. James       3
# 6              7                            McCarthy, Mr. Timothy J       1
# 7              8                     Palsson, Master. Gosta Leonard       3
# 8              9  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       3
# 9             10                Nasser, Mrs. Nicholas (Adele Achem)       2
# 10            11                    Sandstrom, Miss. Marguerite Rut       3
# ...

# %%
titanic.to_string()
# Out:
# '     PassengerId                                                                                Name  Pclass     Sex    Age  SibSp  Parch              Ticket      Fare            Cabin Embarked  Survived\n0              1                                                             Braund, Mr. Owen Harris       3    male  22.00      1      0           A/5 21171    7.2500              NaN        S         0\n1              2                                 Cumings, Mrs. John Bradley (Florence Briggs Thayer)       1  female  38.00      1      0            PC 17599   71.2833              C85        C         1\n2              3                                                              Heikkinen, Miss. Laina       3  female  26.00      0      0    STON/O2. 3101282    7.9250              NaN        S         1\n3              4                                        Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.00      1      0              113803   53.1000          
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Name         891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Sex          891 non-null    object
#  4   Age          714 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Ticket       891 non-null    object
#  8   Fare         891 non-null    float64
#  9   Cabin        204 non-null    object
#  10  Embarked     889 non-null    object
#  11  Survived     891 non-null    int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch  \
# count   891.000000  891.000000  714.000000  891.000000  891.000000
# mean    446.000000    2.308642   29.699118    0.523008    0.381594
# std     257.353842    0.836071   14.526497    1.102743    0.806057
# min       1.000000    1.000000    0.420000    0.000000    0.000000
# 25%     223.500000    2.000000   20.125000    0.000000    0.000000
# 50%     446.000000    3.000000   28.000000    0.000000    0.000000
# 75%     668.500000    3.000000   38.000000    1.000000    0.000000
# max     891.000000    3.000000   80.000000    8.000000    6.000000
#
#              Fare    Survived
# count  891.000000  891.000000
# mean    32.204208    0.383838
# std     49.693429    0.486592
# min      0.000000    0.000000
# 25%      7.910400    0.000000
# 50%     14.454200    0.000000
# 75%     31.000000    1.000000
# max    512.329200    1.000000

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Name             0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Survived         0
# dtype: int64

# %%
dirtydata
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'  110.0       130     409.1
# 1         60  '2020/12/02'  117.0       145     479.0
# 2         60  '2020/12/03'  103.0       135     340.0
# 3         45  '2020/12/04'  109.0       175     282.4
# 4         45  '2020/12/05'  117.0       148     406.0
# 5         60  '2020/12/06'  102.0       127     300.0
# 6         60  '2020/12/07'  110.0       136     374.0
# 7        450  '2020/12/08'  104.0       134     253.3
# 8         30  '2020/12/09'  109.0       133     195.1
# 9         60  '2020/12/10'   98.0       124     269.0
# 10        60  '2020/12/11'  103.0       147     329.3
# 11        60  '2020/12/12'  100.0       120     250.7
# 12        60  '2020/12/12'  100.0       120     250.7
# 13        60  '2020/12/13'    NaN       128     345.3
# 14        60  '2020/12/14'  104.0       132     379.3
# 15        60  '2020/12/15'   98.0       123     275.0
# ...

# %%
new_dirtydata=new_dirtydata.dropna()
new_dirtydata
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'  110.0       130     409.1
# 1         60  '2020/12/02'  117.0       145     479.0
# 2         60  '2020/12/03'  103.0       135     340.0
# 3         45  '2020/12/04'  109.0       175     282.4
# 4         45  '2020/12/05'  117.0       148     406.0
# 5         60  '2020/12/06'  102.0       127     300.0
# 6         60  '2020/12/07'  110.0       136     374.0
# 7        450  '2020/12/08'  104.0       134     253.3
# 8         30  '2020/12/09'  109.0       133     195.1
# 9         60  '2020/12/10'   98.0       124     269.0
# 10        60  '2020/12/11'  103.0       147     329.3
# 11        60  '2020/12/12'  100.0       120     250.7
# 12        60  '2020/12/12'  100.0       120     250.7
# 14        60  '2020/12/14'  104.0       132     379.3
# 15        60  '2020/12/15'   98.0       123     275.0
# 16        60  '2020/12/16'   98.0       120     215.2
# ...

# %%
dirtydata.shape
# Out:
# (32, 5)

# %%
new_dirtydata.shape
# Out:
# (28, 5)

# %%
new_dirtydata.dropna(inplace = True)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_3832\3856184462.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_dirtydata.dropna(inplace = True)

# %%
new_dirtydata.shape
# Out:
# (28, 5)

# %%
dirtydata.fillna(111)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'  110.0       130     409.1
# 1         60  '2020/12/02'  117.0       145     479.0
# 2         60  '2020/12/03'  103.0       135     340.0
# 3         45  '2020/12/04'  109.0       175     282.4
# 4         45  '2020/12/05'  117.0       148     406.0
# 5         60  '2020/12/06'  102.0       127     300.0
# 6         60  '2020/12/07'  110.0       136     374.0
# 7        450  '2020/12/08'  104.0       134     253.3
# 8         30  '2020/12/09'  109.0       133     195.1
# 9         60  '2020/12/10'   98.0       124     269.0
# 10        60  '2020/12/11'  103.0       147     329.3
# 11        60  '2020/12/12'  100.0       120     250.7
# 12        60  '2020/12/12'  100.0       120     250.7
# 13        60  '2020/12/13'  111.0       128     345.3
# 14        60  '2020/12/14'  104.0       132     379.3
# 15        60  '2020/12/15'   98.0       123     275.0
# ...

# %%
new_dirtydata['Pulse']
# Out:
# 0     110.0
# 1     117.0
# 2     103.0
# 3     109.0
# 4     117.0
# 5     102.0
# 6     110.0
# 7     104.0
# 8     109.0
# 9      98.0
# 10    103.0
# 11    100.0
# 12    100.0
# 14    104.0
# 15     98.0
# 16     98.0
# 17    100.0
# 19    103.0
# 20     97.0
# 21    108.0
# 23    130.0
# 24    105.0
# 25    102.0
# 26    100.0
# 27     92.0
# 29    100.0
# 30    102.0
# 31     92.0
# Name: Pulse, dtype: float64

# %%
x=dirtydata['Calories'].mean()
x
# Out:
# 304.68

# %%
dirtydata['Calories'].fillna(x)
# Out:
# 0     409.10
# 1     479.00
# 2     340.00
# 3     282.40
# 4     406.00
# 5     300.00
# 6     374.00
# 7     253.30
# 8     195.10
# 9     269.00
# 10    329.30
# 11    250.70
# 12    250.70
# 13    345.30
# 14    379.30
# 15    275.00
# 16    215.20
# 17    300.00
# 18    304.68
# 19    323.00
# 20    243.00
# 21    364.20
# 22    282.00
# 23    300.00
# 24    246.00
# 25    334.50
# 26    250.00
# 27    241.00
# 28    304.68
# 29    280.00
# 30    380.30
# 31    243.00
# Name: Calories, dtype: float64

# %%
x=dirtydata['Calories'].median()
x
# Out:
# 291.2

# %%
dirtydata['Calories'].fillna(x)
# Out:
# 0     409.1
# 1     479.0
# 2     340.0
# 3     282.4
# 4     406.0
# 5     300.0
# 6     374.0
# 7     253.3
# 8     195.1
# 9     269.0
# 10    329.3
# 11    250.7
# 12    250.7
# 13    345.3
# 14    379.3
# 15    275.0
# 16    215.2
# 17    300.0
# 18    291.2
# 19    323.0
# 20    243.0
# 21    364.2
# 22    282.0
# 23    300.0
# 24    246.0
# 25    334.5
# 26    250.0
# 27    241.0
# 28    291.2
# 29    280.0
# 30    380.3
# 31    243.0
# Name: Calories, dtype: float64

# %%
x=dirtydata['Calories'].mode()
x
# Out:
# 0    300.0
# Name: Calories, dtype: float64

# %%
dirtydata['Calories'].fillna(x)
# Out:
# 0     409.1
# 1     479.0
# 2     340.0
# 3     282.4
# 4     406.0
# 5     300.0
# 6     374.0
# 7     253.3
# 8     195.1
# 9     269.0
# 10    329.3
# 11    250.7
# 12    250.7
# 13    345.3
# 14    379.3
# 15    275.0
# 16    215.2
# 17    300.0
# 18      NaN
# 19    323.0
# 20    243.0
# 21    364.2
# 22    282.0
# 23    300.0
# 24    246.0
# 25    334.5
# 26    250.0
# 27    241.0
# 28      NaN
# 29    280.0
# 30    380.3
# 31    243.0
# Name: Calories, dtype: float64

# %%
pd.to_datetime(new_dirtydata['Date'])
# Out:
# 0    2020-12-01
# 1    2020-12-02
# 2    2020-12-03
# 3    2020-12-04
# 4    2020-12-05
# 5    2020-12-06
# 6    2020-12-07
# 7    2020-12-08
# 8    2020-12-09
# 9    2020-12-10
# 10   2020-12-11
# 11   2020-12-12
# 12   2020-12-12
# 14   2020-12-14
# 15   2020-12-15
# 16   2020-12-16
# 17   2020-12-17
# 19   2020-12-19
# 20   2020-12-20
# 21   2020-12-21
# 23   2020-12-23
# 24   2020-12-24
# 25   2020-12-25
# 26   2020-12-26
# 27   2020-12-27
# 29   2020-12-29
# 30   2020-12-30
# 31   2020-12-31
# Name: Date, dtype: datetime64[ns]

# %%
dirtydata.dropna(subset=['Date','Calories'])
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'  110.0       130     409.1
# 1         60  '2020/12/02'  117.0       145     479.0
# 2         60  '2020/12/03'  103.0       135     340.0
# 3         45  '2020/12/04'  109.0       175     282.4
# 4         45  '2020/12/05'  117.0       148     406.0
# 5         60  '2020/12/06'  102.0       127     300.0
# 6         60  '2020/12/07'  110.0       136     374.0
# 7        450  '2020/12/08'  104.0       134     253.3
# 8         30  '2020/12/09'  109.0       133     195.1
# 9         60  '2020/12/10'   98.0       124     269.0
# 10        60  '2020/12/11'  103.0       147     329.3
# 11        60  '2020/12/12'  100.0       120     250.7
# 12        60  '2020/12/12'  100.0       120     250.7
# 13        60  '2020/12/13'    NaN       128     345.3
# 14        60  '2020/12/14'  104.0       132     379.3
# 15        60  '2020/12/15'   98.0       123     275.0
# ...

# %%
dirtydata.loc[7,'Duration']
# Out:
# 450

# %%
dirtydata.loc[7,'Duration']=45

# %%
dirtydata.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# dtype: bool

# %%
a=dirtydata[dirtydata.duplicated()==True]
a
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 12        60  '2020/12/12'  100.0       120     250.7

# %%
dirtydata.drop(12)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'  110.0       130     409.1
# 1         60  '2020/12/02'  117.0       145     479.0
# 2         60  '2020/12/03'  103.0       135     340.0
# 3         45  '2020/12/04'  109.0       175     282.4
# 4         45  '2020/12/05'  117.0       148     406.0
# 5         60  '2020/12/06'  102.0       127     300.0
# 6         60  '2020/12/07'  110.0       136     374.0
# 7         45  '2020/12/08'  104.0       134     253.3
# 8         30  '2020/12/09'  109.0       133     195.1
# 9         60  '2020/12/10'   98.0       124     269.0
# 10        60  '2020/12/11'  103.0       147     329.3
# 11        60  '2020/12/12'  100.0       120     250.7
# 13        60  '2020/12/13'    NaN       128     345.3
# 14        60  '2020/12/14'  104.0       132     379.3
# 15        60  '2020/12/15'   98.0       123     275.0
# 16        60  '2020/12/16'   98.0       120     215.2
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [46], in <cell line: 1>()
# ----> 1 dirtydata.loc(a)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:634, in _LocationIndexer.__call__(self, axis)
#     631 new_self = type(self)(self.name, self.obj)
#     633 if axis is not None:
# --> 634     axis = self.obj._get_axis_number(axis)
#     635 new_self.axis = axis
#     636 return new_self
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:550, in NDFrame._get_axis_number(cls, axis)
#     546 @final
#     547 @classmethod
#     548 def _get_axis_number(cls, axis: Axis) -> int:
#     549     try:
# --> 550         return cls._AXIS_TO_AXIS_NUMBER[axis]
#     551     except KeyError:
#     552         raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# TypeError: unhashable type: 'DataFrame'

# %%
dirtydata.duplicated().sum()
# Out:
# 1

# %%
dirtydata.drop_duplicates()
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'  110.0       130     409.1
# 1         60  '2020/12/02'  117.0       145     479.0
# 2         60  '2020/12/03'  103.0       135     340.0
# 3         45  '2020/12/04'  109.0       175     282.4
# 4         45  '2020/12/05'  117.0       148     406.0
# 5         60  '2020/12/06'  102.0       127     300.0
# 6         60  '2020/12/07'  110.0       136     374.0
# 7         45  '2020/12/08'  104.0       134     253.3
# 8         30  '2020/12/09'  109.0       133     195.1
# 9         60  '2020/12/10'   98.0       124     269.0
# 10        60  '2020/12/11'  103.0       147     329.3
# 11        60  '2020/12/12'  100.0       120     250.7
# 13        60  '2020/12/13'    NaN       128     345.3
# 14        60  '2020/12/14'  104.0       132     379.3
# 15        60  '2020/12/15'   98.0       123     275.0
# 16        60  '2020/12/16'   98.0       120     215.2
# ...
